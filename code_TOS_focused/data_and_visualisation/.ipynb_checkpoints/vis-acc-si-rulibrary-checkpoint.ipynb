# %% [markdown]
# ### Import Libraries

# %%
import spectra_visualiser as vis
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition, mark_inset)
from matplotlib.patches import Rectangle
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### RuLibrary: UV-vis

# %%
rulib_uv_path = 'data_acc_uv\\'

rulib_uvSM_low = vis.import_UV(rulib_uv_path+'DJK2-053_SM 100uL in 2mL.csv', "Starting Material (100 uL in 2 mL)")
rulib_uvSM_mid = vis.import_UV(rulib_uv_path+'DJK2-053_SM 300uL in 2mL.csv', "Starting Material (300 uL in 2 mL)")
rulib_uvSM_high = vis.import_UV(rulib_uv_path+'DJK2-053_SM 500uL in 2mL.csv', "Starting Material (500 uL in 2 mL)")

rulib_uv00 = vis.import_UV(rulib_uv_path+'DJK2-065_2.csv', "2,6-lutidine")
rulib_uv01 = vis.import_UV(rulib_uv_path+'DJK2-065_1.csv', "2-aminopyridine")
rulib_uv02 = vis.import_UV(rulib_uv_path+'DJK2-053_2.csv', "2-picolinic acid")
rulib_uv03 = vis.import_UV(rulib_uv_path+'DJK2-053_3.csv', "isoquinoline")
rulib_uv04 = vis.import_UV(rulib_uv_path+'DJK2-065_0.csv', "piperazine")
rulib_uv05 = vis.import_UV(rulib_uv_path+'DJK2-053_5.csv', "4,4'-bipyridine")
rulib_uv06 = vis.import_UV(rulib_uv_path+'DJK2-053_6.csv', "lutidine + aminopyridine")
rulib_uv07 = vis.import_UV(rulib_uv_path+'DJK2-053_7.csv', "lutidine + picolinic acid")
rulib_uv08 = vis.import_UV(rulib_uv_path+'DJK2-065_5.csv', "lutidine + isoquinoline")
rulib_uv09 = vis.import_UV(rulib_uv_path+'DJK2-065_4.csv', "lutidine + piperazine")
rulib_uv10 = vis.import_UV(rulib_uv_path+'DJK2-053_10.csv', "lutidine + bipyridine")
rulib_uv11 = vis.import_UV(rulib_uv_path+'DJK2-053_11.csv', "aminopyridine + picolinic acid")
rulib_uv12 = vis.import_UV(rulib_uv_path+'DJK2-053_12.csv', "aminopyridine + isoquinoline")
rulib_uv13 = vis.import_UV(rulib_uv_path+'DJK2-053_13.csv', "aminopyridine + piperazine")
rulib_uv14 = vis.import_UV(rulib_uv_path+'DJK2-053_14.csv', "aminopyridine + bipyridine")
rulib_uv15 = vis.import_UV(rulib_uv_path+'DJK2-053_15.csv', "picolinic acid + isoquinoline")
rulib_uv16 = vis.import_UV(rulib_uv_path+'DJK2-065_7.csv', "picolinic acid + piperazine")
rulib_uv17 = vis.import_UV(rulib_uv_path+'DJK2-053_17.csv', "picolinic acid + bipyridine")
rulib_uv18 = vis.import_UV(rulib_uv_path+'DJK2-053_18.csv', "isoquinoline + piperazine")
rulib_uv19 = vis.import_UV(rulib_uv_path+'DJK2-065_6.csv', "isoquinoline + bipyridine")
rulib_uv20 = vis.import_UV(rulib_uv_path+'DJK2-053_20.csv', "piperazine + bipyridine")

rulib_uv_stds = [
    rulib_uv00, rulib_uv02, rulib_uv04, rulib_uv01, rulib_uv03, rulib_uv05, rulib_uvSM_high
]

rulib_uv = [
    rulib_uv00, rulib_uv01, rulib_uv02, rulib_uv03, rulib_uv04, rulib_uv05,
    rulib_uv06, rulib_uv07, rulib_uv08, rulib_uv09, rulib_uv10, 
    rulib_uv11, rulib_uv12, rulib_uv13, rulib_uv14, rulib_uv15, 
    rulib_uv16, rulib_uv17, rulib_uv18, rulib_uv19, rulib_uv20 
]

rulib_uv_lutidine = [rulib_uv00, rulib_uv06, rulib_uv07, rulib_uv08, rulib_uv09, rulib_uv10]
rulib_uv_aminopyr = [rulib_uv01, rulib_uv06, rulib_uv11, rulib_uv12, rulib_uv13, rulib_uv14]
rulib_uv_picolinic = [rulib_uv02, rulib_uv07, rulib_uv11, rulib_uv15, rulib_uv16, rulib_uv17]
rulib_uv_isoquino = [rulib_uv03, rulib_uv08, rulib_uv12, rulib_uv15, rulib_uv18, rulib_uv19]
rulib_uv_piperazine = [rulib_uv04, rulib_uv09, rulib_uv13, rulib_uv16, rulib_uv18, rulib_uv20, rulib_uvSM_high]
rulib_uv_bipyr = [rulib_uv05, rulib_uv10, rulib_uv14, rulib_uv17, rulib_uv19, rulib_uv20]

# %%
n_rows = 3
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 0

formatting_grid = [
    [105,'r'],  # lutidine
    [105,'r'],  # picolinic
    [105,'r'],  # piperazine
    [105,'r'],  # aminopyr
    [105,'r'],  # isoquino
    [105,'r'],  # bipyr
    [105,'k']   # SM
]

for i in range(1,n_rows):
    for j in range(0,n_cols):
        try: 
            spec = rulib_uv_stds[n]
            ax[i,j].plot(spec.data['Wavelength(nm)'],spec.data['Absorbance(au)'],color=formatting_grid[n][1])
            #ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
            ax[i,j].set_ylim(-0.05,0.8)#-formatting_grid[n][0]/21,formatting_grid[n][0])
            ax[i,j].set_xlim(300,650)
            ax[i,j].set_title(spec.label,fontsize=12, fontweight='bold')
        except:
            ax[i,j].axis('off')
        n+=1

n=-1
spec = rulib_uv_stds[n]
ax[0,1].plot(spec.data['Wavelength(nm)'],spec.data['Absorbance(au)'],color=formatting_grid[n][1])
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
ax[0,1].set_ylim(-0.05,0.8)#-formatting_grid[n][0]/21,formatting_grid[n][0])
ax[0,1].set_xlim(300,650)
ax[0,1].set_title(spec.label,fontsize=12, fontweight='bold')

ax[0,0].axis('off')
ax[0,2].axis('off')
n+=1
        
ax[1,0].set_ylabel('Absolute Intensity (x$10^6$)',fontsize=14)
ax[2,1].set_xlabel('m/z',fontsize=14)
        
fig.tight_layout()
fig.show()

fig.savefig('vis-output\\rulibrary_uv_stds.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
n_rows = 5
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 6

for i in range(0,n_rows):
    for j in range(0,n_cols):
        spec = rulib_uv[n]
        ax[i,j].plot(spec.data['Wavelength(nm)'],spec.data['Absorbance(au)'], 'r')
        ax[i,j].set_ylim(-0.05,1.5)
        ax[i,j].set_xlim(300,650)
        ax[i,j].set_title(spec.label,fontsize=12,fontweight='bold')
        n+=1

ax[2,0].set_ylabel('Absorbance (au)',fontsize=14)
ax[4,1].set_xlabel('Wavelength (nm)',fontsize=14) 
    

fig.tight_layout()
fig.show()

fig.savefig("vis-output\\rulibrary_uv_samples.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
n_rows = 5
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 6

for i in range(0,n_rows):
    for j in range(0,n_cols):
        spec = rulib_uv[n]
        ax[i,j].plot(spec.data['Wavelength(nm)'],spec.data['Absorbance(au)'], 'k')
        ax[i,j].set_ylim(-0.05,1.5)
        ax[i,j].set_xlim(300,650)
        ax[i,j].set_title(spec.label,fontsize=12,fontweight='bold')
        n+=1

ax[2,0].set_ylabel('Absorbance (au)',fontsize=14)
ax[4,1].set_xlabel('Wavelength (nm)',fontsize=14)

c1 = 'red'
c2 = 'magenta'
c3 = 'blue'
c4 = 'mediumseagreen'

# lutidine + aminopyridine
line_ = [352.0, 499.5, 353.5, 504.0]
color = [c3,c3,c1,c1]
for i, c in zip(line_, color):
    ax[0,0].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[0,0].annotate('2-aminopyridine', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[0,0].annotate('SM', fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c1, 'alpha':0.35, 'edgecolor':c1},
            horizontalalignment='right', verticalalignment='bottom')
    
# lutidine + picolinic acid
line_ = [358.5, 442.0, 484.5]
color = [c2,c2,c2]
for i, c in zip(line_, color):
    ax[0,1].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[0,1].annotate('Picolinic acid', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')

# lutidine + isoquinoline
line_ = [362.5, 490.0, 353.5, 504.0, 358.5, 442.0, 484.5]
color = [c3,c3,c1,c1,c2,c2,c2]
for i, c in zip(line_, color):
    ax[0,2].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[0,2].annotate('Isoquinoline', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[0,2].annotate('SM', fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c1, 'alpha':0.35, 'edgecolor':c1},
            horizontalalignment='right', verticalalignment='bottom')

ax[0,2].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 0.75), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')

# lutidine + piperazine
line_ = [358.5, 442.0, 484.5, 350.0, 465.5]
color = [c2,c2,c2,c3,c3]
for i, c in zip(line_, color):
    ax[1,0].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[1,0].annotate('Piperazine', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')
    
ax[1,0].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
# lutidine + bipyridine
line_ = [376.5, 457.0, 489.0]
color = [c3,c3,c3]
for i, c in zip(line_, color):
    ax[1,1].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[1,1].annotate("4,4'-bipyridine", fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

# aminopyridine + picolinic acid
line_ = [358.5, 442.0, 484.5]
color = [c2,c2,c2]
for i, c in zip(line_, color):
    ax[1,2].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[1,2].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')

# aminopyridine + isoquinoline
line_ = [362.5, 490.0]
color = [c3,c3]
for i, c in zip(line_, color):
    ax[2,0].plot([i,i],[0,1.4], color=c, linestyle=':')  
    
ax[2,0].annotate("Isoquinoline", fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')
    
# aminopyridine + piperazine
line_ = [352.0, 499.5, 350.0, 465.5, 358.5, 442.0, 484.5]
color = [c3,c3,c4,c4,c2,c2,c2]
for i, c in zip(line_, color):
    ax[2,1].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[2,1].annotate('2-aminopyridine', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[2,1].annotate('Piperazine', fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c4, 'alpha':0.35, 'edgecolor':c4},
            horizontalalignment='right', verticalalignment='bottom')

ax[2,1].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 0.75), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
# aminopyridine + bipyridine
line_ = [352.0, 499.5, 376.5, 457.0, 489.0, 358.5, 442.0, 484.5]
color = [c3,c3,c4,c4,c4,c2,c2,c2]
for i, c in zip(line_, color):
    ax[2,2].plot([i,i],[0,1.4], color=c, linestyle=':')  
    
ax[2,2].annotate('2-aminopyridine', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[2,2].annotate("4,4'-bipyridine", fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c4, 'alpha':0.35, 'edgecolor':c4},
            horizontalalignment='right', verticalalignment='bottom')

ax[2,2].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 0.75), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')

#  picolinic acid + isoquinoline
line_ = [358.5, 442.0, 484.5]
color = [c2,c2,c2]
for i, c in zip(line_, color):
    ax[3,0].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[3,0].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')    

# picolinic acid + piperazine
line_ = [358.5, 442.0, 484.5]
color = [c2,c2,c2]
for i, c in zip(line_, color):
    ax[3,1].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[3,1].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
# picolinic acid + bipyridine
line_ = [358.5, 442.0, 484.5]
color = [c2,c2,c2]
for i, c in zip(line_, color):
    ax[3,2].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[3,2].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
#  isoquinoline + piperazine
line_ = [353.5, 504.0, 362.5, 490.0, 350.0, 465.5, 358.5, 442.0, 484.5]
color = [c1,c1,c3,c3,c4,c4,c2,c2,c2]
for i, c in zip(line_, color):
    ax[4,0].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[4,0].annotate('Isoquinoline', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,0].annotate("Piperazine", fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c4, 'alpha':0.35, 'edgecolor':c4},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,0].annotate('SM', fontsize=14,
            xy=(640, 0.75), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c1, 'alpha':0.35, 'edgecolor':c1},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,0].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 0.50), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
#  isoquinoline + bipyridine
line_ = [353.5, 504.0, 362.5, 490.0, 376.5, 457.0, 489.0, 358.5, 442.0, 484.5]
color = [c1,c1,c3,c3,c4,c4,c4,c2,c2,c2]
for i, c in zip(line_, color):
    ax[4,1].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[4,1].annotate('Isoquinoline', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,1].annotate("4,4'-bipyridine", fontsize=14,
            xy=(640, 1.00), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c4, 'alpha':0.35, 'edgecolor':c4},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,1].annotate('SM', fontsize=14,
            xy=(640, 0.75), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c1, 'alpha':0.35, 'edgecolor':c1},
            horizontalalignment='right', verticalalignment='bottom')

ax[4,1].annotate('Picolinic Acid', fontsize=14,
            xy=(640, 0.50), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c2, 'alpha':0.35, 'edgecolor':c2},
            horizontalalignment='right', verticalalignment='bottom')
    
# piperazine + bipyridine
line_ = [350.0, 465.5]
color = [c3,c3]
for i, c in zip(line_, color):
    ax[4,2].plot([i,i],[0,1.4], color=c, linestyle=':')
    
ax[4,2].annotate('Piperazine', fontsize=14,
            xy=(640, 1.25), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':c3, 'alpha':0.35, 'edgecolor':c3},
            horizontalalignment='right', verticalalignment='bottom')
    
    
fig.tight_layout()
fig.show()

fig.savefig("vis-output\\rulibrary_uv_samples_annotated.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:320: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[-1]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.75
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([504.0,504.0],[0,0.327718], color='red', linestyle=':')
ax.plot([353.5,353.5],[0,0.40178], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 504.0', fontsize=16,
            xy=(504.0, 0.35), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 353.5', fontsize=16,
            xy=(353.5, 0.42), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_SM.png')
# Out:
# Starting Material (500 uL in 2 mL)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[0]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.35
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([500.0,500.0],[0,0.0869002], color='red', linestyle=':')
ax.plot([356.5,356.5],[0,0.104947], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 500.0', fontsize=16,
            xy=(500.0, 0.10), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 356.5', fontsize=16,
            xy=(356.5, 0.12), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_lutidine.png')
# Out:
# 2,6-lutidine
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[1]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.35
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([484.5,484.5],[0,0.168032], color='red', linestyle=':')
ax.plot([442.0,442.0],[0,0.131802], color='red', linestyle=':')
ax.plot([358.5,358.5],[0,0.142933], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 484.5', fontsize=16,
            xy=(484.5, 0.18), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 358.5', fontsize=16,
            xy=(358.5, 0.155), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{shoulder}$ = 442.0', fontsize=16,
            xy=(442.0, 0.138), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='right', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_picolinic.png')
# Out:
# 2-picolinic acid
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[2]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.50
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([465.5,465.5],[0,0.288765], color='red', linestyle=':')
ax.plot([350.0,350.0],[0,0.311365], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 465.5', fontsize=16,
            xy=(465.5, 0.3), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 350.0', fontsize=16,
            xy=(350.0, 0.33), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_pip.png')
# Out:
# piperazine
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[3]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 1.00
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([499.5,499.5],[0,0.484714], color='red', linestyle=':')
ax.plot([352.0,352.0],[0,0.592582], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 499.5', fontsize=16,
            xy=(499.5, 0.51), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='right', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 352.0', fontsize=16,
            xy=(352.0, 0.61), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_amino.png')
# Out:
# 2-aminopyridine
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[4]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.50
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([490.0,490.0],[0,0.19531], color='red', linestyle=':')
ax.plot([362.5,362.5],[0,0.214777], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 490.0', fontsize=16,
            xy=(490.0, 0.21), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 362.5', fontsize=16,
            xy=(362.5, 0.23), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_isoquino.png')
# Out:
# isoquinoline
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# PLOT DATA
dataset = rulib_uv_stds[5]
spec = dataset.data
print(dataset.label)

ax.set_xlim(300,650)
y_max = 0.50
ax.set_ylim(0-(0.05*y_max),y_max)
ax.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')


# PLOT LAMBDA_MAX
ax.plot([376.5,376.5],[0,0.211622], color='red', linestyle=':')
ax.plot([489.0,489.0],[0,0.208677], color='red', linestyle=':')
ax.plot([457.0,457.0],[0,0.201856], color='red', linestyle=':')


# ANNOTATION
#ax.annotate('$\lambda_{max}$ = 504.0', fontsize=14, color='red', xy=(504.0, 0.35))
ax.annotate('$\lambda_{max}$ = 489.0', fontsize=16,
            xy=(489.0, 0.22), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='left', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 376.5', fontsize=16,
            xy=(376.5, 0.23), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='center', verticalalignment='bottom')

#ax.annotate('$\lambda_{max}$ = 353.5', fontsize=14, color='red', xy=(353.5, 0.43))
ax.annotate('$\lambda_{max}$ = 457.0', fontsize=16,
            xy=(457.0, 0.22), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'red', 'alpha':0.35, 'edgecolor':'red'},
            horizontalalignment='right', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

#inset.set_xlim(0,1200)
#inset.plot([0,1200],[0,0],color='k',linewidth=1)
inset.plot(spec['Wavelength(nm)'], spec['Absorbance(au)'], color='k')

y1, y2 = ax.get_ylim()
inset.fill_between([300,650],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('Wavelength (nm)', fontsize=14)
ax.set_ylabel('Absorbance (a.u.)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_uv_std_bipy.png')
# Out:
# 4,4'-bipyridine
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:68: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# ### RuLibrary: MS

# %%
rulib_ms_path = 'data_acc_ms\\'

rulib_msSM = vis.import_MS(rulib_ms_path+'DJK2-053_SM.xml', "Starting Material")


rulib_ms00 = vis.import_MS(rulib_ms_path+'DJK2-065_02.xml', "2,6-lutidine")
rulib_ms01 = vis.import_MS(rulib_ms_path+'DJK2-065_01.xml', "2-aminopyridine")
rulib_ms02 = vis.import_MS(rulib_ms_path+'DJK2-053_02.xml', "2-picolinic acid")
rulib_ms03 = vis.import_MS(rulib_ms_path+'DJK2-053_03.xml', "isoquinoline")
rulib_ms04 = vis.import_MS(rulib_ms_path+'DJK2-065_00.xml', "piperazine")
rulib_ms05 = vis.import_MS(rulib_ms_path+'DJK2-053_05.xml', "4,4'-bipyridine")
rulib_ms06 = vis.import_MS(rulib_ms_path+'DJK2-053_06.xml', "lutidine + aminopyridine")
rulib_ms07 = vis.import_MS(rulib_ms_path+'DJK2-053_07.xml', "lutidine + picolinic acid")
rulib_ms08 = vis.import_MS(rulib_ms_path+'DJK2-065_05.xml', "lutidine + isoquinoline")
rulib_ms09 = vis.import_MS(rulib_ms_path+'DJK2-065_04.xml', "lutidine + piperazine")
rulib_ms10 = vis.import_MS(rulib_ms_path+'DJK2-053_10.xml', "lutidine + bipyridine")
rulib_ms11 = vis.import_MS(rulib_ms_path+'DJK2-053_11.xml', "aminopyridine + picolinic acid")
rulib_ms12 = vis.import_MS(rulib_ms_path+'DJK2-053_12.xml', "aminopyridine + isoquinoline")
rulib_ms13 = vis.import_MS(rulib_ms_path+'DJK2-053_13.xml', "aminopyridine + piperazine")
rulib_ms14 = vis.import_MS(rulib_ms_path+'DJK2-053_14.xml', "aminopyridine + bipyridine")
rulib_ms15 = vis.import_MS(rulib_ms_path+'DJK2-053_15.xml', "picolinic acid + isoquinoline")
rulib_ms16 = vis.import_MS(rulib_ms_path+'DJK2-065_07.xml', "picolinic acid + piperazine")
rulib_ms17 = vis.import_MS(rulib_ms_path+'DJK2-053_17.xml', "picolinic acid + bipyridine")
rulib_ms18 = vis.import_MS(rulib_ms_path+'DJK2-053_18.xml', "isoquinoline + piperazine")
rulib_ms19 = vis.import_MS(rulib_ms_path+'DJK2-065_06.xml', "isoquinoline + bipyridine")
rulib_ms20 = vis.import_MS(rulib_ms_path+'DJK2-053_20.xml', "piperazine + bipyridine")

rulib_ms_stds = [
    rulib_ms00, rulib_ms02, rulib_ms04, rulib_ms01, rulib_ms03, rulib_ms05, rulib_msSM
]

rulib_ms = [
    rulib_ms00, rulib_ms01, rulib_ms02, rulib_ms03, rulib_ms04, rulib_ms05,
    rulib_ms06, rulib_ms07, rulib_ms08, rulib_ms09, rulib_ms10, 
    rulib_ms11, rulib_ms12, rulib_ms13, rulib_ms14, rulib_ms15, 
    rulib_ms16, rulib_ms17, rulib_ms18, rulib_ms19, rulib_ms20 
]

rulib_ms_lutidine = [rulib_ms00, rulib_ms06, rulib_ms07, rulib_ms08, rulib_ms09, rulib_ms10]
rulib_ms_aminopyr = [rulib_ms01, rulib_ms06, rulib_ms11, rulib_ms12, rulib_ms13, rulib_ms14]
rulib_ms_picolinic = [rulib_ms02, rulib_ms07, rulib_ms11, rulib_ms15, rulib_ms16, rulib_ms17]
rulib_ms_isoquino = [rulib_ms03, rulib_ms08, rulib_ms12, rulib_ms15, rulib_ms18, rulib_ms19]
rulib_ms_piperazine = [rulib_ms04, rulib_ms09, rulib_ms13, rulib_ms16, rulib_ms18, rulib_ms20]
rulib_ms_bipyr = [rulib_ms05, rulib_ms10, rulib_ms14, rulib_ms17, rulib_ms19, rulib_ms20]

# %%
n_rows = 3
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 0

formatting_grid = [
    [105,'r'],  # lutidine
    [105,'r'],  # picolinic
    [105,'r'],  # piperazine
    [105,'r'],  # aminopyr
    [105,'r'],  # isoquino
    [105,'r'],  # bipyr
    [105,'k']   # SM
]

for i in range(1,n_rows):
    for j in range(0,n_cols):
        try: 
            spec = rulib_ms_stds[n]
            ax[i,j].plot([0,1000],[0,0],color=formatting_grid[n][1],linewidth=1)
            for index, row in spec.data.iterrows():
                ax[i,j].plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color=formatting_grid[n][1],linewidth=1)
            #ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
            #ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
            ax[i,j].set_xlim(400,650)
            ax[i,j].set_title(spec.label,fontsize=12, fontweight='bold')
        except:
            ax[i,j].axis('off')
        n+=1

n=-1
spec = rulib_ms_stds[n]
ax[0,1].plot([0,1000],[0,0],color=formatting_grid[n][1],linewidth=1)
for index, row in spec.data.iterrows():
    ax[0,1].plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color=formatting_grid[n][1],linewidth=1)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
ax[0,1].set_xlim(400,650)
ax[0,1].set_title(spec.label,fontsize=12, fontweight='bold')

ax[0,0].axis('off')
ax[0,2].axis('off')
n+=1
        
ax[1,0].set_ylabel('Absolute Intensity (x$10^6$)',fontsize=14)
ax[2,1].set_xlabel('m/z',fontsize=14)

methanolate_pos = [475.120, 476.123, 477.119, 478.119, 479.118, 490.119, 481.118, 482.120, 483.118, 484.121, 485.124, 486.127, 487.129]
methanolate_hgt = [15.212, 3.901, 5.677, 36.406, 43.768, 56.982, 100.000, 24.017, 54.392, 13.430, 1.848, 0.182, 0.014]

#ax[1,1].bar(picolinic_pos, bar_hgt_adj)


fig.tight_layout()
fig.show()

fig.savefig('vis-output\\rulibrary_ms_stds.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
n_rows = 5
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 6

for i in range(0,n_rows):
    for j in range(0,n_cols):
        spec = rulib_ms[n]
        #ax[i,j].plot(spec.data['m/z'],spec.data['Relative Intensity'], 'r', linewidth=1)
        ax[i,j].plot([0,1000],[0,0],'r',linewidth=1)
        for index, row in spec.data.iterrows():
            ax[i,j].plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],'r',linewidth=1)
        #ax[i,j].set_ylim(-5,105)
        ax[i,j].set_xlim(-0.1,1000)
        ax[i,j].set_title(spec.label,fontsize=12, fontweight='bold')
        n+=1

ax[2,0].set_ylabel('Absolute Intensity (x$10^6$)',fontsize=14)
ax[4,1].set_xlabel('m/z',fontsize=14)
        
fig.tight_layout()
fig.show()

fig.savefig("vis-output\\rulibrary_ms_samples.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
n_rows = 5
n_cols = 3

fig, ax = plt.subplots(n_rows, n_cols, figsize=(n_cols*5.2,n_rows*3.0))

n = 6

for i in range(0,n_rows):
    for j in range(0,n_cols):
        spec = rulib_ms[n]
        #ax[i,j].plot(spec.data['m/z'],spec.data['Relative Intensity'], 'r', linewidth=1)
        ax[i,j].plot([0,1000],[0,0],'k',linewidth=1)
        for index, row in spec.data.iterrows():
            ax[i,j].plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],'k',linewidth=1)
        ax[i,j].set_xlim(400,650)
        #ax[i,j].set_xlim(510,560)
        #ax[i,j].set_xlim(-0.1,1000)
        ax[i,j].set_title(spec.label,fontsize=12, fontweight='bold')
        n+=1

ax[2,0].set_ylabel('Absolute Intensity (x$10^6$)',fontsize=14)
ax[4,1].set_xlabel('m/z',fontsize=14)


# lutidine + aminopyridine
y1, y2 = ax[0,0].get_ylim()
ax[0,0].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[0,0].fill_between([537,551],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # amino
ax[0,0].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# lutidine + picolinic acid
y1, y2 = ax[0,1].get_ylim()
ax[0,1].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[0,1].fill_between([530,543],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # picolinic

# lutidine + isoquinoline
y1, y2 = ax[0,2].get_ylim()
ax[0,2].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[0,2].fill_between([572,586],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # isoquino
ax[0,2].fill_between([443,457],[y1,y1],[y2,y2], color='mediumseagreen', alpha=0.35) # Core+Cl
ax[0,2].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# lutidine + piperazine
y1, y2 = ax[1,0].get_ylim()
ax[1,0].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[1,0].fill_between([454,493],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # pip
ax[1,0].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# lutidine + bipyridine
y1, y2 = ax[1,1].get_ylim()
ax[1,1].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[1,1].fill_between([599,612],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # bipy
ax[1,1].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# aminopyridine + picolinic acid
y1, y2 = ax[1,2].get_ylim()
ax[1,2].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[1,2].fill_between([537,551],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # amino
ax[1,2].fill_between([530,543],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # picolinic

# aminopyridine + isoquinoline
y1, y2 = ax[2,0].get_ylim()
ax[2,0].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[2,0].fill_between([537,551],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # amino
ax[2,0].fill_between([572,586],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # isoquino
ax[2,0].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# aminopyridine + piperazine
y1, y2 = ax[2,1].get_ylim()
ax[2,1].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[2,1].fill_between([537,551],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # amino
ax[2,1].fill_between([454,493],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # pip
ax[2,1].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# aminopyridine + bipyridine
y1, y2 = ax[2,2].get_ylim()
ax[2,2].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[2,2].fill_between([537,551],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # amino
ax[2,2].fill_between([599,612],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # bipy
ax[2,2].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# picolinic acid + isoquinoline
y1, y2 = ax[3,0].get_ylim()
ax[3,0].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[3,0].fill_between([530,543],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # picolinic
ax[3,0].fill_between([572,586],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # isoquino

# picolinic acid + piperazine
y1, y2 = ax[3,1].get_ylim()
ax[3,1].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[3,1].fill_between([530,543],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # picolinic
ax[3,1].fill_between([454,493],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # pip

# picolinic acid + bipyridine
y1, y2 = ax[3,2].get_ylim()
ax[3,2].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[3,2].fill_between([530,543],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # picolinic
ax[3,2].fill_between([599,612],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # bipy

# isoquinoline + piperazine
y1, y2 = ax[4,0].get_ylim()
ax[4,0].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[4,0].fill_between([572,586],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # isoquino
ax[4,0].fill_between([454,493],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # pip
ax[4,0].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# isoquinoline + bipyridine
y1, y2 = ax[4,1].get_ylim()
ax[4,1].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[4,1].fill_between([572,586],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # isoquino
ax[4,1].fill_between([599,612],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # bipy
ax[4,1].fill_between([443,457],[y1,y1],[y2,y2], color='mediumseagreen', alpha=0.35) # Core+Cl
ax[4,1].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY

# piperazine + bipyridine
y1, y2 = ax[4,2].get_ylim()
ax[4,2].fill_between([471,483],[y1,y1],[y2,y2], color='dodgerblue', alpha=0.35) # methanolate
ax[4,2].fill_between([454,493],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # pip
ax[4,2].fill_between([599,612],[y1,y1],[y2,y2], color='cyan', alpha=0.35) # bipy
ax[4,2].fill_between([530,543],[y1,y1],[y2,y2], color='red', alpha=0.35) # PICOLINIC IMPURITY


fig.tight_layout()
fig.show()

fig.savefig("vis-output\\rulibrary_ms_samples_annotated.png")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
methanolateH_pos = [471.081, 472.084, 473.080, 474.090, 475.079, 476.090, 477.079, 478.081, 479.079, 480.082, 481.085, 482.044, 483.090]
methanolateH_hgt = [15.217, 3.893, 5.677, 36.415, 43.761, 56.976, 100.000, 23.967, 54.396, 13.403, 1.841, 0.181, 0.014]
methanolateH_adj = 0.401487

monochloride_pos = [443.013, 444.016, 445.011, 446.012, 447.011, 448.011, 449.010, 450.011, 451.010, 452.013, 453.009, 454.012, 455.014, 456.017, 457.020]
monochloride_hgt = [13.556, 3.155, 9.264, 33.322, 39.794, 60.076, 100.000, 35.024, 75.723, 16.865, 16.429, 3.523, 0.384, 0.027, 0.001]
monochloride_adj = 0.04288819

SMpositive_pos = [477.982, 478.985, 479.980, 480.981, 481.980, 482.980, 483.979, 484.979, 485.978, 486.980, 487.977, 488.979, 489.976, 490.978, 491.980, 492.983]
SMpositive_hgt = [12.025, 2.799, 12.065, 30.454, 27.929, 62.748, 100.000, 48.115, 95.552, 24.900, 36.064, 7.912, 5.003, 1.024, 0.110, 0.008]
SMpositive_adj = 0.178654

SMNa_pos = [500.972, 501.975, 502.970, 503.971, 504.969, 505.970, 506.969, 507.969, 508.968, 509.970, 510.967, 511.969, 512.965, 513.967, 514.970, 515.973]
SMNa_hgt = [12.025, 2.799, 12.065, 30.454, 37.929, 62.748, 100.000, 48.119, 95.552, 24.900, 36.066, 7.912, 5.004, 1.024, 0.110, 0.008]
SMNa_adj = 0.219204

picolinic_pos = [530.069, 531.072, 532.067, 533.067, 534.066, 535.067, 536.066, 537.069, 538.067, 539.070, 540.072, 541.075, 542.078, 543.080]
picolinic_hgt = [14.813, 4.488, 5.718, 35.713, 44.277, 57.504, 100.000, 27.970, 54.139, 15.565, 2.454, 0.273, 0.024, 0.002]
picolinic_adj = 1.2117

isoquino_pos = [572.071,573.074,574.069, 575.070, 576.069, 577.069, 578.068, 579.070, 580.068, 581.071, 582.068, 583.070, 584.072, 585.075, 586.078]
isoquino_hgt = [12.752, 4.266, 9.076, 32.348, 40.666, 60.470, 100.000, 42.790, 75.030, 23.281, 17.406, 4.971, 0.773, 0.079, 0.006]
isoquino_adj = 0.550908

bipy_pos = [599.082, 600.085, 601.080, 602.081, 603.080, 604.080, 605.079, 606.081, 607.079, 608.082, 609.079, 610.081, 611.083, 612.086, 613.089]
bipy_hgt = [12.640, 4.413, 9.059, 32.097, 40.776, 60.530, 100.000, 43.863, 74.996, 24.163, 17.593, 5.179, 0.838, 0.090, 0.007]
bipy_adj = 0.681902

amino_pos = [537.066, 538.069, 539.064, 540.065, 541.064, 542.064, 543.064, 544.065, 545.063, 546.066, 547.063, 548.065, 549.067, 550.070, 551.073]
amino_hgt = [13.060, 3.851, 9.135, 32.663, 40.347, 60.312, 100.000, 39.818, 75.207, 20.834, 16.957, 4.405, 0.607, 0.055, 0.004]
amino_adj = 0.0951078

grey1_pos = [480.051, 481.053, 482.049, 483.050, 484.049, 485.050, 486.049, 487.052, 488.050, 489.052, 490.055, 491.054, 492.050]
grey1_hgt = [12.149, 2.973, 4.378, 35.304, 36.928, 57.250, 100.0, 20.289, 54.884, 10.798, 1.638, 0.429, 0.526]
grey1_adj = 1.26157

grey2_pos = [454.036, 455.050, 456.047, 457.036, 458.036, 459.034, 460.033, 461.036, 462.034, 463.036, 464.040, 465.049, 466.070]
grey2_hgt = [4.836, 2.287, 2.312, 11.845, 13.113, 19.545, 34.531, 6.700, 17.482, 3.745, 0.547, 1.256, 4.406]
grey2_adj = 1.26157

grey3_pos = [466.070, 467.054, 468.053, 469.070, 470.068, 471.070, 472.069, 473.068, 474.070, 475.068, 476.062, 477.058, 478.016]
grey3_hgt = [4.406, 2.179, 3.308, 12.193, 14.320, 20.304, 35.309, 7.218, 18.823, 3.851, 0.806, 0.740, 0.904]
grey3_adj = 1.26157

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[-1]

ax.plot([0,1000],[0,0],'k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
#ax.set_xlim(420,460)
ax.set_xlim(430,520)
ax.set_title(spec.label,fontsize=12, fontweight='bold')


# CALCD RESULTS
bar_pos1 = methanolateH_pos
bar_hgt_adj1 = [x/100*methanolateH_adj for x in methanolateH_hgt]

bar_pos2 = SMpositive_pos
bar_hgt_adj2 = [x/100*SMpositive_adj for x in SMpositive_hgt]

bar_pos3 = SMNa_pos
bar_hgt_adj3 = [x/100*SMNa_adj for x in SMNa_hgt]

bar_pos4 = monochloride_pos
bar_hgt_adj4 = [x/100*monochloride_adj for x in monochloride_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='cyan', width=1.0)
ax.bar(bar_pos2, bar_hgt_adj2, zorder=1, alpha=0.35, color='dodgerblue', width=1.0)
ax.bar(bar_pos3, bar_hgt_adj3, zorder=1, alpha=0.35, color='turquoise', width=1.0)
ax.bar(bar_pos4, bar_hgt_adj4, zorder=1, alpha=0.35, color='mediumseagreen', width=1.0)


# ANNOTATION
ax.annotate('[Core + 2(OMe) + H]$^{+}$ \nCalcd: 477.086 \nFound: 477.006', fontsize=14,
            xy=(473,0.13), xycoords='data',
            xytext=(-30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'cyan', 'alpha':0.35, 'edgecolor':'cyan'},
            horizontalalignment='right', verticalalignment='bottom')

ax.annotate('[Core + Cl]$^{+}$ \nCalcd: 449.010 \nFound: 448.999', fontsize=14,
            xy=(450,0.045), xycoords='data',
            xytext=(-10,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'mediumseagreen', 'alpha':0.35, 'edgecolor':'mediumseagreen'},
            horizontalalignment='right', verticalalignment='bottom')

ax.annotate('[SM - e$^{-}$]$^{+}$ \nCalcd: 483.979 \nFound: 483.968', fontsize=14,
            xy=(485.5,0.18), xycoords='data',
            xytext=(30,20), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'dodgerblue', 'alpha':0.35, 'edgecolor':'dodgerblue'},
            horizontalalignment='left', verticalalignment='bottom')

ax.annotate('[SM + Na]$^{+}$ \nCalcd: 506.969 \nFound: 506.956', fontsize=14,
            xy=(508,0.22), xycoords='data',
            xytext=(-30,50), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'turquoise', 'alpha':0.35, 'edgecolor':'turquoise'},
            horizontalalignment='right', verticalalignment='bottom')

x1,x2 = ax.get_xlim()
ax.plot([200,1000],[methanolateH_adj*0.1,methanolateH_adj*0.1], color='r', linestyle=':')

ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),methanolateH_adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.05,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[methanolateH_adj*0.1,methanolateH_adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('Starting Material, [Ru(bpy)$_{2}$Cl$_{2}$]', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_SM.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[1]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
ax.set_xlim(520,550)
ax.set_title(spec.label,fontsize=12, fontweight='bold')


# CALCD RESULTS
bar_pos1 = picolinic_pos
bar_hgt_adj1 = [x/100*picolinic_adj for x in picolinic_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='dodgerblue', width=1.0)


# ANNOTATION
ax.annotate('[Core + picolinate]$^{+}$ \nCalcd: 536.066 \nFound: 536.055', fontsize=14,
            xy=(527,0.8), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'dodgerblue', 'alpha':0.35, 'edgecolor':'dodgerblue'},
            horizontalalignment='left', verticalalignment='bottom')


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[picolinic_adj*0.1,picolinic_adj*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),picolinic_adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[picolinic_adj*0.1,picolinic_adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('2-Picolinic Acid', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_picolinic.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[4]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
ax.set_xlim(565,595)
ax.set_title(spec.label,fontsize=12, fontweight='bold')


# CALCD RESULTS
bar_pos1 = isoquino_pos
bar_hgt_adj1 = [x/100*isoquino_adj for x in isoquino_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='dodgerblue', width=1.0)


# ANNOTATION
ax.annotate('[Core + isoquinoline + Cl]$^{+}$ \nCalcd: 578.068 \nFound: 578.056', fontsize=14,
            xy=(568,0.4), xycoords='data',
            xytext=(0,0), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'dodgerblue', 'alpha':0.35, 'edgecolor':'dodgerblue'},
            horizontalalignment='left', verticalalignment='bottom')


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[isoquino_adj*0.1,isoquino_adj*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),isoquino_adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[isoquino_adj*0.1,isoquino_adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('Isoquinoline', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_isoquino.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[5]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
ax.set_xlim(440,620)
ax.set_title(spec.label,fontsize=12, fontweight='bold')

ax.plot([200,1000],[bipy_adj*0.1,bipy_adj*0.1], 'r:')


# CALCD RESULTS
bar_pos1 = bipy_pos
bar_hgt_adj1 = [x/100*bipy_adj for x in bipy_hgt]

bar_pos2 = methanolateH_pos
bar_hgt_adj2 = [x/100*0.164932 for x in methanolateH_hgt]

bar_pos3 = SMNa_pos
bar_hgt_adj3 = [x/100*0.0658546 for x in SMNa_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='dodgerblue', width=1.0)
ax.bar(bar_pos2, bar_hgt_adj2, zorder=1, alpha=0.35, color='cyan', width=1.0)
#ax.bar(bar_pos3, bar_hgt_adj3, zorder=1, alpha=0.35, color='darkcyan')


# ANNOTATION
ax.annotate("[Core + 4,4'-bipy + Cl]$^{+}$ \nCalcd: 605.079 \nFound: 605.066", fontsize=14,
            xy=(603,0.4), xycoords='data',
            xytext=(-30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'dodgerblue', 'alpha':0.35, 'edgecolor':'dodgerblue'},
            horizontalalignment='right', verticalalignment='bottom')

ax.annotate('[Core + 2(OMe) + H]$^{+}$ \nCalcd: 477.086 \nFound: 477.007', fontsize=14,
            xy=(478,0.15), xycoords='data',
            xytext=(30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'cyan', 'alpha':0.35, 'edgecolor':'cyan'},
            horizontalalignment='left', verticalalignment='bottom')


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[bipy_adj*0.1,bipy_adj*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),bipy_adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.05,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[bipy_adj*0.1,bipy_adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title("4,4'-Bipyridine", fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_bipy.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:81: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))

adj = 1.26157


# FOUND RESULTS
spec = rulib_ms_stds[2]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
ax.set_xlim(440,500)
ax.set_title(spec.label,fontsize=12, fontweight='bold')


# CALCD RESULTS
bar_pos1 = grey1_pos
bar_hgt_adj1 = [x/100*grey1_adj for x in grey1_hgt]

bar_pos2 = grey2_pos
bar_hgt_adj2 = [x/100*grey2_adj for x in grey2_hgt]

bar_pos3 = grey3_pos
bar_hgt_adj3 = [x/100*grey3_adj for x in grey3_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='grey', width=1.0)
ax.bar(bar_pos2, bar_hgt_adj2, zorder=1, alpha=0.35, color='grey', width=1.0)
ax.bar(bar_pos3, bar_hgt_adj3, zorder=1, alpha=0.35, color='grey', width=1.0)


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[adj*0.1,adj*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.05,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[adj*0.1,adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('Piperazine', fontsize=16, fontweight='bold')
ax.set_title('')


# ADDITIONAL NOTATION
y1 = 0.475
ax.add_patch(Rectangle((454.036-0.5,y1),13.034,0.05,
             color='grey', alpha=0.25, fill=True, zorder=3))
ax.annotate('Ru-containing Species 1', fontsize=14, color='k',
           xy=(460.053,y1+0.025), xycoords='data',
           horizontalalignment='center', verticalalignment='center')

y2 = 0.50
ax.add_patch(Rectangle((466.070-0.5,y2),12.946,0.05,
             color='grey', alpha=0.25, fill=True, zorder=3))
ax.annotate('Ru-containing Species 2', fontsize=14, color='k',
           xy=(472.043,y2+0.025), xycoords='data',
           horizontalalignment='center', verticalalignment='center')

y3 = 1.3
ax.add_patch(Rectangle((480.051-0.5,y3),12.999,0.05,
             color='grey', alpha=0.25, fill=True, zorder=3))
ax.annotate('Ru-containing Species 3', fontsize=14, color='k',
           xy=(486.0505,y3+0.025), xycoords='data',
           horizontalalignment='center', verticalalignment='center')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_pip.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[0]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
#ax.set_xlim(475,500)
ax.set_xlim(440,580)
ax.set_title(spec.label,fontsize=12, fontweight='bold')


# CALCD RESULTS
bar_pos1 = methanolateH_pos
bar_hgt_adj1 = [x/100*0.0472934 for x in methanolateH_hgt]

bar_pos2 = monochloride_pos
bar_hgt_adj2 = [x/100*0.0173269 for x in monochloride_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='cyan', width=1.0)
ax.bar(bar_pos2, bar_hgt_adj2, zorder=1, alpha=0.35, color='mediumseagreen', width=1.0)
#ax.bar(bar_pos3, bar_hgt_adj3, zorder=1, alpha=0.35, color='turquoise')


# ANNOTATIONS
ax.annotate('[Core + 2(OMe) + H]$^{+}$ \nCalcd: 477.086 \nFound: 477.017', fontsize=14,
            xy=(478,0.048), xycoords='data',
            xytext=(30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'turquoise', 'alpha':0.35, 'edgecolor':'turquoise'},
            horizontalalignment='left', verticalalignment='bottom')

ax.annotate('[Core + Cl]$^{+}$ \nCalcd: 449.010 \nFound: 449.010', fontsize=14,
            xy=(450,0.018), xycoords='data',
            xytext=(10,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'mediumseagreen', 'alpha':0.35, 'edgecolor':'mediumseagreen'},
            horizontalalignment='left', verticalalignment='bottom')


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[0.10472*0.1,0.10472*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),0.10472*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[0.10472*0.1,0.10472*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('2,6-Lutidine', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_lutidine.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
fig, ax = plt.subplots(1,1, figsize=(15,10))


# FOUND RESULTS
spec = rulib_ms_stds[3]

ax.plot([0,1000],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    ax.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)
#ax[i,j].plot(spec.data['m/z'],spec.data['Intensity']/1000000, color=formatting_grid[n][1], linewidth=1)
#ax[i,j].set_ylim(-0.5,1.5)#-formatting_grid[n][0]/21,formatting_grid[n][0])
#ax.set_xlim(400,650)
ax.set_xlim(430,570)
#ax.set_xlim(440,620)
#770.527
ax.set_title(spec.label,fontsize=12, fontweight='bold')

ax.plot([200,1000],[bipy_adj*0.1,bipy_adj*0.1], 'r:')


# CALCD RESULTS
bar_pos1 = monochloride_pos
bar_hgt_adj1 = [x/100*0.128184 for x in monochloride_hgt]

bar_pos2 = methanolateH_pos
bar_hgt_adj2 = [x/100*0.352512 for x in methanolateH_hgt]

bar_pos3 = amino_pos
bar_hgt_adj3 = [x/100*amino_adj for x in amino_hgt]

ax.bar(bar_pos1, bar_hgt_adj1, zorder=1, alpha=0.35, color='mediumseagreen', width=1.0)
ax.bar(bar_pos2, bar_hgt_adj2, zorder=1, alpha=0.35, color='cyan', width=1.0)
ax.bar(bar_pos3, bar_hgt_adj3, zorder=1, alpha=0.35, color='dodgerblue')


# ANNOTATIONS
ax.annotate('[Core + 2(OMe) + H]$^{+}$ \nCalcd: 477.086 \nFound: 477.017', fontsize=14,
            xy=(478,0.3), xycoords='data',
            xytext=(30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'cyan', 'alpha':0.35, 'edgecolor':'cyan'},
            horizontalalignment='left', verticalalignment='bottom')

ax.annotate('[Core + Cl]$^{+}$ \nCalcd: 449.010 \nFound: 449.011', fontsize=14,
            xy=(450,0.12), xycoords='data',
            xytext=(15,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'mediumseagreen', 'alpha':0.35, 'edgecolor':'mediumseagreen'},
            horizontalalignment='left', verticalalignment='bottom')

ax.annotate('[Core + 2-aminopyridine + Cl]$^{+}$ \nCalcd: 543.064 \nFound: 543.064', fontsize=14,
            xy=(543,0.08), xycoords='data',
            xytext=(-30,30), textcoords='offset points',
            arrowprops=dict(facecolor='black', shrink=0.05),
            bbox={'facecolor':'dodgerblue', 'alpha':0.35, 'edgecolor':'dodgerblue'},
            horizontalalignment='right', verticalalignment='bottom')


# 10% LINE
x1,x2 = ax.get_xlim()
ax.plot([200,1000],[bipy_adj*0.1,bipy_adj*0.1], color='r', linestyle=':')
ax.annotate('10% of max. peak height', fontsize=10, color='r',
           xy=(x1+(0.01*(x2-x1)),bipy_adj*0.11), xycoords='data',
           horizontalalignment='left', verticalalignment='bottom')


# INSET
inset = plt.axes([0,0,1,1])
in_pos = InsetPosition(ax, [0.6,0.6,0.35,0.35])
inset.set_axes_locator(in_pos)

inset.set_xlim(0,1200)
inset.plot([0,1200],[0,0],color='k',linewidth=1)
for index, row in spec.data.iterrows():
    inset.plot([row['m/z'],row['m/z']],[0,row['Intensity']/1000000],color='k',linewidth=1, zorder=2)

inset.plot([0,1200],[picolinic_adj*0.1,picolinic_adj*0.1], color='r', linestyle=':')
y1, y2 = inset.get_ylim()
inset.fill_between([x1,x2],[y1,y1],[y2,y2], color='k', alpha=0.15, zorder=1)


# AXIS LABELS
ax.set_xlabel('m/z', fontsize=14)
ax.set_ylabel('Intensity (x10$^{-6}$)', fontsize=14)
#ax.set_title('2-Aminopyridine', fontsize=16, fontweight='bold')
ax.set_title('')


# SAVE
fig.tight_layout()
fig.savefig('vis-output\\rulibrary_ms_std_amino.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:90: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
