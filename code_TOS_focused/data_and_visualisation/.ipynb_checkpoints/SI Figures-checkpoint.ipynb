# %%
import carboxy as cbx
import pandas as pd
import numpy as np
import spectra_visualiser as vis
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Common Component

# %%
cce1 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\CCE\\CCE_1_legible.csv',index_col=0)
cce1 = cce1.drop(['prime1','prime2'],axis=0)
cce2 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\CCE\\CCE_2_legible.csv',index_col=0)
cce2 = cce2.drop(['prime1','prime2'],axis=0)
cce3 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\CCE\\CCE_3_legible.csv',index_col=0)
cce3 = cce3.drop(['prime1','prime2'],axis=0)
cce4 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\CCE\\CCE_4_legible.csv',index_col=0)
cce4 = cce4.drop(['prime1','prime2'],axis=0)

cce_res = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\CCE\\CCE_4_result_AMF.csv',index_col=0)

# %%
arr = np.array(cce_res['AMF'])
cce = pd.concat([cce1,cce2,cce3,cce4])
cce['AMF'] = arr
cce.replace(0.00, np.nan, inplace=True)
cce.columns = ['{Co3O(OH)}','{Co3O}','{Co4O4}','T1: Ce','T1: Dy','T1: Yb','T2: OA','T2: SA','T2: TMTACN','MeOH','AMF']
cce
# Out:
#              {Co3O(OH)}  {Co3O}  {Co4O4}  T1: Ce  T1: Dy  T1: Yb  T2: OA  \
# Reaction ID
# CCE_1_0            1.70    2.98     0.67     NaN     NaN    0.59     NaN
# CCE_1_1            3.08    0.80     0.46     NaN    0.82     NaN     NaN
# CCE_1_2            1.20    3.94     1.66     2.2     NaN     NaN     NaN
# CCE_1_3            2.89    2.36     2.30     NaN     NaN     NaN     NaN
# CCE_1_4            3.92    0.35     1.74     NaN     NaN    2.11     NaN
# ...                 ...     ...      ...     ...     ...     ...     ...
# CCE_4_43           0.25    0.03     0.50     NaN     NaN     NaN     NaN
# CCE_4_44           1.61    0.79     0.81     NaN     NaN     NaN     NaN
# CCE_4_45           1.19    1.50     1.97     NaN     NaN     NaN     NaN
# CCE_4_46           0.26     NaN     4.45     NaN     NaN     NaN     NaN
# CCE_4_47           0.06     NaN     2.29     NaN     NaN    0.28     NaN
#
#              T2: SA  T2: TMTACN  MeOH       AMF
# Reaction ID
# ...

# %%
fig, ax = plt.subplots(10,10, figsize=(15,15), sharex='col', sharey='row')

color1 = 'indigo'       # cluster + cluster
color2 = 'darkviolet'   # cluster + template
color3 = 'violet'       # cluster + solvent
color4 = 'blue'         # template + template
color5= 'DarkCyan'      # solvent + template
color6 = 'g'            # solvent + solvent
color_prev = 'grey'

data = cce
cols = data.columns

range_cluster = 7.5
range_template = 7.5
range_solv = 7.5

cmap='plasma'

size = 3

# Co3O(OH)
rec1 = ax[9,0].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec1.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,0], zorder=2)
data.plot.scatter(x=cols[1], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,1])
data.plot.scatter(x=cols[2], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,2])
data.plot.scatter(x=cols[3], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,3])
data.plot.scatter(x=cols[4], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,4])
data.plot.scatter(x=cols[5], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,5])
data.plot.scatter(x=cols[6], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,6])
data.plot.scatter(x=cols[7], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,7])
data.plot.scatter(x=cols[8], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,8])
data.plot.scatter(x=cols[9], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,9])

# Co3O
rec2 = ax[8,1].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec2.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,0])
data.plot.scatter(x=cols[1], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,1], zorder=2)
data.plot.scatter(x=cols[2], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,2])
data.plot.scatter(x=cols[3], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,3])
data.plot.scatter(x=cols[4], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,4])
data.plot.scatter(x=cols[5], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,5])
data.plot.scatter(x=cols[6], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,6])
data.plot.scatter(x=cols[7], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,7])
data.plot.scatter(x=cols[8], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,8])
data.plot.scatter(x=cols[9], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,9])

# Co4O4
rec3 = ax[7,2].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec3.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,0])
data.plot.scatter(x=cols[1], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,1])
data.plot.scatter(x=cols[2], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,2], zorder=2)
data.plot.scatter(x=cols[3], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,3])
data.plot.scatter(x=cols[4], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,4])
data.plot.scatter(x=cols[5], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,5])
data.plot.scatter(x=cols[6], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,6])
data.plot.scatter(x=cols[7], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,7])
data.plot.scatter(x=cols[8], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,8])
data.plot.scatter(x=cols[9], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,9])

# Ce
rec4 = ax[6,3].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec4.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,0])
data.plot.scatter(x=cols[1], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,1])
data.plot.scatter(x=cols[2], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,2])
data.plot.scatter(x=cols[3], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,3], zorder=2)
ax[6,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
ax[6,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[6], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,6])
data.plot.scatter(x=cols[7], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,7])
data.plot.scatter(x=cols[8], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,8])
data.plot.scatter(x=cols[9], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,9])

# Dy
rec5 = ax[5,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec5.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,0])
data.plot.scatter(x=cols[1], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,1])
data.plot.scatter(x=cols[2], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,2])
ax[5,3].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[4], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,4], zorder=2)
ax[5,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[6], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,6])
data.plot.scatter(x=cols[7], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,7])
data.plot.scatter(x=cols[8], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,8])
data.plot.scatter(x=cols[9], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,9])

# Yb
rec6 = ax[4,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec6.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,0])
data.plot.scatter(x=cols[1], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,1])
data.plot.scatter(x=cols[2], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,2])
ax[4,3].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
ax[4,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[5], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,5], zorder=2)
data.plot.scatter(x=cols[6], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,6])
data.plot.scatter(x=cols[7], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,7])
data.plot.scatter(x=cols[8], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,8])
data.plot.scatter(x=cols[9], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,9])

# OA
rec7 = ax[3,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec7.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,0])
data.plot.scatter(x=cols[1], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,1])
data.plot.scatter(x=cols[2], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,2])
data.plot.scatter(x=cols[3], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,3])
data.plot.scatter(x=cols[4], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,4])
data.plot.scatter(x=cols[5], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,5])
data.plot.scatter(x=cols[6], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,6], zorder=2)
ax[3,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
ax[3,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[9], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,9])

# SA
rec8 = ax[2,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec8.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,0])
data.plot.scatter(x=cols[1], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,1])
data.plot.scatter(x=cols[2], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,2])
data.plot.scatter(x=cols[3], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,3])
data.plot.scatter(x=cols[4], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,4])
data.plot.scatter(x=cols[5], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,5])
ax[2,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[7], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,7], zorder=2)
ax[2,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[9], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,9])

# TMTACN
rec9 = ax[1,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec9.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,0])
data.plot.scatter(x=cols[1], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,1])
data.plot.scatter(x=cols[2], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,2])
data.plot.scatter(x=cols[3], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,3])
data.plot.scatter(x=cols[4], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,4])
data.plot.scatter(x=cols[5], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,5])
ax[1,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
ax[1,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[8], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,8], zorder=2)
data.plot.scatter(x=cols[9], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,9])

# MeOH
rec10 = ax[0,9].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_solv, range_solv, color='lightgrey'))
rec10.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,0])
data.plot.scatter(x=cols[1], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,1])
data.plot.scatter(x=cols[2], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,2])
data.plot.scatter(x=cols[3], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,3])
data.plot.scatter(x=cols[4], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,4])
data.plot.scatter(x=cols[5], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,5])
data.plot.scatter(x=cols[6], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,6])
data.plot.scatter(x=cols[7], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,7])
data.plot.scatter(x=cols[8], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,8])
data.plot.scatter(x=cols[9], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,9], zorder=2)

fig.savefig('search-space-cce.png')

# %% [markdown]
# # Isostructural

# %%
ise1 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\ISE\\ISE_1_legible.csv',index_col=0)
ise1 = ise1.drop(['prime1','prime2'],axis=0)
ise2 = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\ISE\\ISE_2_legible.csv',index_col=0)
ise2 = ise2.drop(['prime1','prime2'],axis=0)

ise_res = pd.read_csv('C:\\Users\\group\\Carboxylates\\notebooks\\Explorations\\ISE\\ISE_2_result_AMF.csv',index_col=0)

# %%
arr = np.array(ise_res['AMF'])
ise = pd.concat([ise1,ise2])
ise['AMF'] = arr
ise.replace(0.00, np.nan, inplace=True)
ise.columns = ['{Cr3O}','{Mn3O}','{Fe3O}','{Co3O}','T1: Ce','T1: Dy','T1: Yb','T2: OA','T2: SA','T2: TMTACN','MeOH','AMF']
ise
# Out:
#              {Cr3O}  {Mn3O}  {Fe3O}  {Co3O}  T1: Ce  T1: Dy  T1: Yb  T2: OA  \
# Reaction ID
# ISE_1_0        2.70    1.00    0.48    1.22    0.87     NaN     NaN    0.01
# ISE_1_1        0.61    0.94    1.70    1.91     NaN     NaN    1.00     NaN
# ISE_1_2        0.59    1.31    2.16    1.59     NaN     NaN    0.61     NaN
# ISE_1_3        1.29    0.61    1.12    0.61     NaN     NaN    0.90     NaN
# ISE_1_4        0.17    0.97    1.38    1.64    0.16     NaN     NaN     NaN
# ...             ...     ...     ...     ...     ...     ...     ...     ...
# ISE_2_43       1.26    1.59    1.61    0.54     NaN    0.89     NaN     NaN
# ISE_2_44       0.57    0.09    0.44    1.80     NaN    0.98     NaN     NaN
# ISE_2_45       0.90    0.74    0.85    0.94     NaN    0.74     NaN     NaN
# ISE_2_46       1.63    0.80    1.63    0.59     NaN    0.63     NaN     NaN
# ISE_2_47       1.38    0.96    1.72    0.23     NaN    0.90     NaN     NaN
#
# ...

# %%
fig, ax = plt.subplots(11,11, figsize=(15,15), sharex='col', sharey='row')

color1 = 'indigo'       # cluster + cluster
color2 = 'darkviolet'   # cluster + template
color3 = 'violet'       # cluster + solvent
color4 = 'blue'         # template + template
color5= 'DarkCyan'      # solvent + template
color6 = 'g'            # solvent + solvent
color_prev = 'grey'

data = ise
cols = data.columns

range_cluster = 4.5
range_template = 4.5
range_solv = 7.5

cmap='plasma'

size = 3

# Cr3O
rec1 = ax[10,0].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec1.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,0], zorder=2)
data.plot.scatter(x=cols[1], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,1])
data.plot.scatter(x=cols[2], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,2])
data.plot.scatter(x=cols[3], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,3])
data.plot.scatter(x=cols[4], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,4])
data.plot.scatter(x=cols[5], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,5])
data.plot.scatter(x=cols[6], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,6])
data.plot.scatter(x=cols[7], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,7])
data.plot.scatter(x=cols[8], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,8])
data.plot.scatter(x=cols[9], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,9])
data.plot.scatter(x=cols[10], y=cols[0], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[10,10])

# Mn3O
rec2 = ax[9,1].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec2.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,0])
data.plot.scatter(x=cols[1], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,1], zorder=2)
data.plot.scatter(x=cols[2], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,2])
data.plot.scatter(x=cols[3], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,3])
data.plot.scatter(x=cols[4], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,4])
data.plot.scatter(x=cols[5], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,5])
data.plot.scatter(x=cols[6], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,6])
data.plot.scatter(x=cols[7], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,7])
data.plot.scatter(x=cols[8], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,8])
data.plot.scatter(x=cols[9], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,9])
data.plot.scatter(x=cols[10], y=cols[1], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[9,10])

# Fe3O
rec3 = ax[8,2].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_cluster, range_cluster, color='lightgrey'))
rec3.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,0])
data.plot.scatter(x=cols[1], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,1])
data.plot.scatter(x=cols[2], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,2], zorder=2)
data.plot.scatter(x=cols[3], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,3])
data.plot.scatter(x=cols[4], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,4])
data.plot.scatter(x=cols[5], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,5])
data.plot.scatter(x=cols[6], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,6])
data.plot.scatter(x=cols[7], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,7])
data.plot.scatter(x=cols[8], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,8])
data.plot.scatter(x=cols[9], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,9])
data.plot.scatter(x=cols[10], y=cols[2], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[8,10])

# Co3O
rec4 = ax[7,3].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec4.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,0])
data.plot.scatter(x=cols[1], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,1])
data.plot.scatter(x=cols[2], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,2])
data.plot.scatter(x=cols[3], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,3], zorder=2)
data.plot.scatter(x=cols[4], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,4])
data.plot.scatter(x=cols[5], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,5])
data.plot.scatter(x=cols[6], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,6])
data.plot.scatter(x=cols[7], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,7])
data.plot.scatter(x=cols[8], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,8])
data.plot.scatter(x=cols[9], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,9])
data.plot.scatter(x=cols[10], y=cols[3], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[7,10])

# Ce
rec5 = ax[6,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec5.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,0])
data.plot.scatter(x=cols[1], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,1])
data.plot.scatter(x=cols[2], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,2])
data.plot.scatter(x=cols[3], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,3])
data.plot.scatter(x=cols[4], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,4], zorder=2)
#data.plot.scatter(x=cols[5], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,5])
ax[6,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
#data.plot.scatter(x=cols[6], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,6])
ax[6,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[7], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,7])
data.plot.scatter(x=cols[8], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,8])
data.plot.scatter(x=cols[9], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,9])
data.plot.scatter(x=cols[10], y=cols[4], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[6,10])

# Dy
rec6 = ax[5,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec6.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,0])
data.plot.scatter(x=cols[1], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,1])
data.plot.scatter(x=cols[2], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,2])
data.plot.scatter(x=cols[3], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,3])
#data.plot.scatter(x=cols[4], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,4])
ax[5,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[5], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,5], zorder=2)
#data.plot.scatter(x=cols[6], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,6])
ax[5,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[7], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,7])
data.plot.scatter(x=cols[8], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,8])
data.plot.scatter(x=cols[9], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,9])
data.plot.scatter(x=cols[10], y=cols[5], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[5,10])

# Yb
rec7 = ax[4,6].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec7.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,0])
data.plot.scatter(x=cols[1], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,1])
data.plot.scatter(x=cols[2], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,2])
data.plot.scatter(x=cols[3], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,3])
#data.plot.scatter(x=cols[4], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,4])
ax[4,4].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
#data.plot.scatter(x=cols[5], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,5])
ax[4,5].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[6], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,6], zorder=2)
data.plot.scatter(x=cols[7], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,7])
data.plot.scatter(x=cols[8], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,8])
data.plot.scatter(x=cols[9], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,9])
data.plot.scatter(x=cols[10], y=cols[6], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[4,10])

# OA
rec8 = ax[3,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec8.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,0])
data.plot.scatter(x=cols[1], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,1])
data.plot.scatter(x=cols[2], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,2])
data.plot.scatter(x=cols[3], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,3])
data.plot.scatter(x=cols[4], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,4])
data.plot.scatter(x=cols[5], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,5])
data.plot.scatter(x=cols[6], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,6])
data.plot.scatter(x=cols[7], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,7], zorder=2)
#data.plot.scatter(x=cols[8], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,8])
ax[3,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
#data.plot.scatter(x=cols[9], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,9])
ax[3,9].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[10], y=cols[7], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[3,10])

# SA
rec9 = ax[2,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec9.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,0])
data.plot.scatter(x=cols[1], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,1])
data.plot.scatter(x=cols[2], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,2])
data.plot.scatter(x=cols[3], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,3])
data.plot.scatter(x=cols[4], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,4])
data.plot.scatter(x=cols[5], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,5])
data.plot.scatter(x=cols[6], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,6])
#data.plot.scatter(x=cols[7], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,7])
ax[2,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[8], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,8], zorder=2)
#data.plot.scatter(x=cols[9], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,9])
ax[2,9].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[10], y=cols[8], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[2,10])

# TMTACN
rec10 = ax[1,9].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='lightgrey'))
rec10.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,0])
data.plot.scatter(x=cols[1], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,1])
data.plot.scatter(x=cols[2], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,2])
data.plot.scatter(x=cols[3], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,3])
data.plot.scatter(x=cols[4], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,4])
data.plot.scatter(x=cols[5], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,5])
data.plot.scatter(x=cols[6], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,6])
#data.plot.scatter(x=cols[7], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,7])
ax[1,7].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
#data.plot.scatter(x=cols[8], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,8])
ax[1,8].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_template, range_template, color='grey'))
data.plot.scatter(x=cols[9], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,9], zorder=2)
data.plot.scatter(x=cols[10], y=cols[9], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[1,10])

# MeOH
rec11 = ax[0,10].add_patch(matplotlib.patches.Rectangle((-0.1,-0.1), range_solv, range_solv, color='lightgrey'))
rec11.set_zorder=1
data.plot.scatter(x=cols[0], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,0])
data.plot.scatter(x=cols[1], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,1])
data.plot.scatter(x=cols[2], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,2])
data.plot.scatter(x=cols[3], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,3])
data.plot.scatter(x=cols[4], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,4])
data.plot.scatter(x=cols[5], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,5])
data.plot.scatter(x=cols[6], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,6])
data.plot.scatter(x=cols[7], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,7])
data.plot.scatter(x=cols[8], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,8])
data.plot.scatter(x=cols[9], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,9])
data.plot.scatter(x=cols[10], y=cols[10], c=data['AMF'], cmap=cmap, colorbar=False, s=size, ax=ax[0,10], zorder=2)

fig.savefig('search-space-ise.png')
